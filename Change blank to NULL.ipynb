# %%
import pandas as pd

# %%
df = pd.read_csv('CovidVaccinations.csv', na_values='')

# %%
df.head()
# Out:
#   iso_code continent     location     date  new_tests  total_tests  \
# 0      AFG      Asia  Afghanistan  24/2/20        NaN          NaN
# 1      AFG      Asia  Afghanistan  25/2/20        NaN          NaN
# 2      AFG      Asia  Afghanistan  26/2/20        NaN          NaN
# 3      AFG      Asia  Afghanistan  27/2/20        NaN          NaN
# 4      AFG      Asia  Afghanistan  28/2/20        NaN          NaN
#
#    total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 0                       NaN                     NaN                 NaN
# 1                       NaN                     NaN                 NaN
# 2                       NaN                     NaN                 NaN
# 3                       NaN                     NaN                 NaN
# 4                       NaN                     NaN                 NaN
#
#    new_tests_smoothed_per_thousand  ...  gdp_per_capita  extreme_poverty  \
# ...

# %%
df.to_csv('covidvaccinationsnew.csv',index=False,na_rep='NULL')
